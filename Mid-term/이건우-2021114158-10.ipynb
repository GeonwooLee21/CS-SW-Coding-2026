# %%
max_palindrome = 0
a, b = 0, 0
for num in range(10000, 998002):
    palindrome = list(f"{num}")
    if palindrome[::] == palindrome[-1::-1]:
        for i in range(100, 1000):
            if num % i == 0 and (num/i >= 100 and num/i < 1000):
                if max_palindrome < num:
                    max_palindrome = num
                    a, b = i, int(num/i)

print(f"대칭수: {max_palindrome}, 인수: {a}, {b}")
# Out:
# 대칭수: 906609, 인수: 913, 993
