# %% [markdown]
# # Mar. 19th - 3rd week

# %% [markdown]
# ## Lab 2-1

# %%
print('나의 이름은 :', '이건우')
print('나의 나이는 :', '24')
print("나의 키는", 170, 'cm 입니다.')
print('10 + 20 =', 10 + 20, '10 * 20 =', 10 * 20)

# %% [markdown]
# ## Lab 2-2

# %% [markdown]
# ## Lab 2-3

# %%
# 1. [코드 2 - 4]를 수정하여 다음과 같이 원의 반지름이 8.0일 때 원의 둘레와 면적을 출력하여라(변수값 radius를 8.0으로 변경하는 방식을 사용하여라)
radius = 8.0
print('원의 반지름', radius)
print('원의 면적', 3.14 * radius * radius)
print('원의 둘레', 2.0 * 3.14 * radius)

# %%
# 1. [코드 2 - 4]를 수정하여 다음과 같이 원의 반지름이 10.0일 때 원의 둘레와 면적을 출력하여라
radius = 10.0
print('원의 반지름', radius)
print('원의 면적', 3.14 * radius * radius)
print('원의 둘레', 2.0 * 3.14 * radius)

# %%
# 3. 사각형의 면적을 구하기 위하여 width(너비)와 height(높이)라는 변수를 이용하도록 하자.
# 이 값이 각각 100, 200이 되도록 변수를 생성한 후 두 변수를 곱하여 다음과 같은 결과가 나오도록 rectangle_test.py 스크립트를 작성하여라
width = 100
height = 200
print('너비', width, ', 높이', height, '인 사각형의 면적 :', width * height)

# %% [markdown]
# ## Lab 2-4

# %%
name = '전우치'
print('나의 이름은 :', name)
age = 27
print('나의 나이는 :', age)
height = 179
print('나의 키는', height, 'cm 입니다.')
sum = 10 + 20
print('10 + 20 =', sum)
mult = 10 * 20
print('10 * 20 =', mult)

# %% [markdown]
# ## Lab 2-5

# %%
# 다음 코드를 작성하고 실행해 보자. 이 코드는 어떤 에러를 유발할까? 또 이 에러를 어떻게 수정해야 할까?
# invalid syntax 에러가 발생한다. global은 키워드(or 예약어)로 미리 지정된 역할을 수행하도록 예약된 단어이므로 변수이름으로 사용할 수 없기 때문이다.
global = 300
print(global)

# %%
# 2. 다음 코드는 어디에서 에러가 발생할까?
# 2번째 라인에서 'Height'가 아니라 'height'로 변수명을 정했기 때문에, 3번째 라인의 'Height'에서 NameError가 발생한다.
width = 20
height = 40
area = ( width * Height )
print('사각형의 면적', area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       3 width = 20
#       4 height = 40
# ----> 5 area = ( width * Height )
#       6 print('사각형의 면적', area)
#
# NameError: name 'Height' is not defined

# %%
# 2번 코드의 에러를 수정하여 너비가 20, 높이가 40인 사각형의 면적을 다음과 같이 출력해 보자.
width = 20
height = 40
area = ( width * height )
print('사각형의 면적 :', area)
# Out:
# 사각형의 면적 : 800

# %%
# 3. 다음 코드는 어떤 문제가 있을까?
# 1) 이 코드는 에러를 출력하는가? 아니오
# 2) 이 코드는 어떤 측면에서 문제점이 있는가?
#    나이를 저장하는 변수명이 'iixxjjkk'라는 나이와는 전혀 관련없는 변수명이 지정되었기 때문에, 해당 변수는 코드의 가독성을 떨어뜨릴 수 있다.
#    좋은 변수 이름을 선택해야 코드를 쉽게 이해할 수 있다!
iixxjjkk = 20
print('나의 나이는', iixxjjkk, '세 입니다')
# Out:
# 나의 나이는 20 세 입니다

# %% [markdown]
# ## Lab 2-6

# %%
# 다음과 같은 코드는 최종적으로 어떤 결과를 출력할까? 출력 결과를 미리 예상해 보고 코딩해 보자.
# 변수 area엔 20 * 40의 값이 아닌 30 * 40의 결과가 담길 것이다.
width = 20
height = 40
width = 30
area = width * height
print('사각형의 면적', area)
# Out:
# 사각형의 면적 1200

# %% [markdown]
# ## Lab 2-7

# %%
# 1. 다음과 같은 계싼을 파이썬 대화창에서 수행하고 그 결과를 적으시오.
print("1)", 123 * 456)
print("2)", 1357+ 2468)
print("3)", 5 ** 4)
print("4)", 20 / 4)
print("5)", 20 // 5)
print("6)", 20 % 5)
# Out:
# 1) 56088
# 2) 3825
# 3) 625
# 4) 5.0
# 5) 4
# 6) 0

# %%
# 2. 5를 2로 나눈 나머지를 구하시오. 이를 구하기 위한 파이썬 수식을 적으시오.
print(5 % 2)
# Out:
# 1

# %%
# 3. 2의 제곱근과 3의 제곱근을 ** 연산자를 사용하여 각각 구하시오.
print('2의 제곱근 :', 2 ** (0.5))
print('3의 제곱근 :', 3 ** (0.5))
# Out:
# 2의 제곱근 : 1.4142135623730951
# 3의 제곱근 : 1.7320508075688772

# %% [markdown]
# ## Lab 2-8

# %%
# 1. 복소수의 a = 8 + 2i, b = 4 + 3i의 두 복소수에 대하여 다음 연산 결과를 적으시오.
a = 8 + 2j
b = 4 + 3j
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
# Out:
# a + b = (12+5j)
# a - b = (4-1j)
# a * b = (26+32j)
# a / b = (1.52-0.64j)

# %% [markdown]
# ## Lab 2-9

# %%
# 정수를 반으로 나누어 가며 얻는 수를 계산해 보고 연속적으로 두 배로 만들어 2^x 값을 생성해 보는 일을 비트 연산으로 할 수 있다.
# 다음과 같이 a라는 변수에 대하여 비트 연산을 적용시키고 그 결과를 출력하시오.
a = 1024
a
1
print('1)', a)
a >> 2
print('2)', a)
a = a >> 1
a
print('3)', a)
a = a >> 1
a
print('4)', a)
a = 1
a << 1
print('5)', a)
a = a << 1
print('6)', a)
a = a << 1
print('7)', a)
a = a << 1
print('8)', a)
a = a << 1
print('9)', a)
# Out:
# 1) 1024
# 2) 1024
# 3) 512
# 4) 256
# 5) 1
# 6) 2
# 7) 4
# 8) 8
# 9) 16

# %% [markdown]
# ## Lab 2-10

# %%
# 1. 다음 코드의 수행 결과는 무엇인가? 빈칸에 들어갈 알맞은 내용을 적으시오.
name = input('이름을 입력하세요 : ')
print(name, '님이 입장하셨습니다.')

# %%
# 2. 다음 코드의 수행 결과는 무엇인가? 빈칸에 들어갈 알맞은 내용을 적으시오.
m = int(input('숫자 m을 입력하세요 : '))
n = int(input('숫자 n을 입력하세요 : '))
print('m + n =', m + n)
print('m - n =', m - n)

# %%
# 3. 사용자로부터 원의 반지름을 정수로 입력받아 이 원의 면적을 출력하여라.
pi = 3.14159
radius = int(input('원의 반지름 r을 입력하세요 : '))
print('원의 면적 :', pi * (radius ** 2))
